# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\tukum\\PYthonvscode\\DLproject\\Kidney-Disease-Classification\\research'

# %%
# Out:
# C:\Users\tukum\PYthonvscode\DLproject\Kidney-Disease-Classification

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\tukum\\PYthonvscode\\DLproject\\Kidney-Disease-Classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size



class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    def download_file(self) -> str:
        try:
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file

            os.makedirs(os.path.dirname(zip_download_dir), exist_ok=True)

            logger.info(f"Downloading data from {dataset_url}")

            file_id = dataset_url.split("/")[-2]
            prefix = "https://drive.google.com/uc?id="

            gdown.download(prefix + file_id, zip_download_dir, quiet=False)

            logger.info(f"Downloaded file at {zip_download_dir}")

        except Exception as e:
            raise e

    def extract_zip_file(self):
        try:
            unzip_path = self.config.unzip_dir
            os.makedirs(unzip_path, exist_ok=True)

            with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
                zip_ref.extractall(unzip_path)

            logger.info(f"Extracted zip file to {unzip_path}")

        except Exception as e:
            raise e

# %%
import yaml

with open("config/config.yaml", "r") as f:
    print(yaml.safe_load(f))
# Out:
# {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/data_ingestion', 'source_URL': 'https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing', 'local_data_file': 'artifacts/data_ingestion/data.zip', 'unzip_dir': 'artifacts/data_ingestion'}}

# %%
import cnnClassifier.utils.common as common
print(common.__file__)
# Out:
# C:\Users\tukum\PYthonvscode\DLproject\Kidney-Disease-Classification\src\cnnClassifier\utils\common.py

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-05-05 19:56:39,036: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-05-05 19:56:39,040: INFO: common: yaml file: params.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File ~\PYthonvscode\DLproject\Kidney-Disease-Classification\src\cnnClassifier\utils\common.py:33, in read_yaml(path_to_yaml)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 33         return ConfigBox(content)
#      34 except BoxValueError:
#
# File c:\Users\tukum\PYthonvscode\DLproject\Kidney-Disease-Classification\.venv\Lib\site-packages\box\box.py:259, in Box.__init__(self, default_box, default_box_attr, default_box_none_transform, default_box_create_on_get, frozen_box, camel_killer_box, conversion_box, modify_tuples_box, box_safe_prefix, box_duplicates, box_intact_types, box_recast, box_dots, box_class, *args, **kwargs)
#     258     else:
# --> 259         raise BoxValueError("First argument must be mapping or iterable")
#     260 elif args:
#
# BoxValueError: First argument must be mapping or iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 8
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#       5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[42], line 8
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#       5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[38], line 8, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       4         config_filepath = CONFIG_FILE_PATH,
#       5         params_filepath = PARAMS_FILE_PATH):
#       6
#       7         self.config = read_yaml(config_filepath)
# ----> 8         self.params = read_yaml(params_filepath)
#       9
#      10         create_directories([self.config.artifacts_root])
#
# File c:\Users\tukum\PYthonvscode\DLproject\Kidney-Disease-Classification\.venv\Lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File ~\PYthonvscode\DLproject\Kidney-Disease-Classification\src\cnnClassifier\utils\common.py:35, in read_yaml(path_to_yaml)
#      33         return ConfigBox(content)
#      34 except BoxValueError:
# ---> 35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
#      37     raise e
#
# ValueError: yaml file is empty
